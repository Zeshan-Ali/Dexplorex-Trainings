# %% [markdown]
# # conditional Programming
# based on some condition
# sp we use comparison operators
#
# i.e compare beweeen two values
#
# 1. '>'      greater then      3> 2    ---> True
# 2. <      lessthen          2<3     ---> True
# 3. <=      less than or equal to     2 <= 3
# 4. '>= greater then or equal to'
# 5. ==   equal to
# 6. !=  not equal to

# %%
3<2
# Out:
# False

# %% [markdown]
# 5 >2

# %%
5>2
# Out:
# True

# %%
a = 90 
b = 90

# %%
a == b
# Out:
# True

# %% [markdown]
# # conditional statements in python
# * if
# * if-else
# * if-elif

# %%
marks > 40
# Out:
# True

# %%
# if
# Out:
# enter your marks: 30

# %%
marks = int(input("enter your marks:"))
if marks > 40:
    print("pass")
else:
    print("fail")
# Out:
# enter your marks: 30
# fail

# %%
a = int(input("Enter a:"))
b  = int(input("Enter b:"))
if a >= b:
    print("A is greater")
else:
    print("B is greater")
# Out:
# Enter a: 4
# Enter b: 3
# A is greater

# %%
num = int(input("enter a number:"))
if num > 0:
    print("positive")
elif num < 0:
    print("negative")
else:
    print("the num is  0")
# Out:
# enter a number: -8
# negative
